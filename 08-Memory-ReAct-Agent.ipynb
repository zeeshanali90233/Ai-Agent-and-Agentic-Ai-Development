# %% [markdown]
# ## Memory in AI Agents
#
# Memory in AI agents refers to the ability of an agent to **store, recall, and use past information** to improve its decision-making and responses.
#
# Types of memory in AI agents:
# - **Short-term memory (STM):** Keeps temporary context during a conversation or task.
# - **Long-term memory (LTM):** Stores knowledge, facts, or experiences for future interactions.
# - **Episodic memory:** Records past events or interactions with timestamps.
# - **Semantic memory:** Retains structured knowledge such as rules, concepts, or facts.
#
# Memory allows AI agents to:
# - Maintain context over multiple turns.
# - Personalize interactions based on user history.
# - Learn continuously from past experiences.
# - Adapt behavior for better efficiency and accuracy.

# %%
from langchain.agents import create_agent

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="API_KEY",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant"
)

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "Do you know my name/?"}]},
    config={"configurable": {"thread_id": "user123"}}
)

# Last Message
print(response['messages'][-1])
# Out:
# content='I do not know your name. I am a large language model, trained by Google.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--70ff7218-0013-48c3-ba15-9d3033261eda-0' usage_metadata={'input_tokens': 51, 'output_tokens': 83, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}

# %% [markdown]
# ### Short Term Memory
#
# Short-term memory lets your application remember previous interactions within a single thread or conversation. A thread organizes multiple interactions in a session, similar to the way email groups messages in a single conversation.

# %%
from langchain.agents import create_agent

from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.checkpoint.memory import InMemorySaver

llm = ChatGoogleGenerativeAI(
    api_key="<API-KEY>",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


# Create an agent with Checkpointer Memory
memory = InMemorySaver()

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
    checkpointer=memory
)

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "Do you know my name"}]},
    config={"configurable": {"thread_id": "1234567"}}
)

# Last Message
print(response['messages'][-1])
# Out:
# content='Yes, your name is Zeeshan Ali.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--b5c7af34-3aee-413d-a451-6d03bd5aca67-0' usage_metadata={'input_tokens': 226, 'output_tokens': 48, 'total_tokens': 274, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 38}}

# %%
# !pip install langgraph-checkpoint-mongodb
# !pip install pymongo
# Out:
# Collecting langgraph-checkpoint-mongodb
#   Using cached langgraph_checkpoint_mongodb-0.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-mongodb>=0.6.1 (from langgraph-checkpoint-mongodb)
#   Using cached langchain_mongodb-0.7.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.23 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langgraph-checkpoint-mongodb) (2.1.1)
# Collecting pymongo<4.15,>=4.12 (from langgraph-checkpoint-mongodb)
#   Using cached pymongo-4.14.1-cp313-cp313-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: langchain-core>=0.2.38 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.3.75)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (1.10.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<4.15,>=4.12->langgraph-checkpoint-mongodb)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.4.16)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (3.0.0)
# Requirement already satisfied: langchain-text-splitters>=0.3 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (0.3.9)
# Requirement already satisfied: langchain>=0.3 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (0.3.27)
# Collecting lark<2.0.0,>=1.1.9 (from langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb)
#   Using cached lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy>=1.26 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (2.3.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (2.32.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.3->langchain-mongodb>=0.6.1->langgraph-checkpoint-mongodb) (3.2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.24.0)
# Requirement already satisfied: anyio in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<3.0.0,>=2.0.23->langgraph-checkpoint-mongodb) (1.3.1)
# Using cached langgraph_checkpoint_mongodb-0.2.0-py3-none-any.whl (12 kB)
# Using cached pymongo-4.14.1-cp313-cp313-win_amd64.whl (956 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached langchain_mongodb-0.7.0-py3-none-any.whl (60 kB)
# Using cached lark-1.2.2-py3-none-any.whl (111 kB)
# Installing collected packages: lark, dnspython, pymongo, langchain-mongodb, langgraph-checkpoint-mongodb
#
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    ---------------------------------------- 0/5 [lark]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    -------- ------------------------------- 1/5 [dnspython]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ---------------- ----------------------- 2/5 [pymongo]
#    ------------------------ --------------- 3/5 [langchain-mongodb]
#    ------------------------ --------------- 3/5 [langchain-mongodb]
#    ------------------------ --------------- 3/5 [langchain-mongodb]
#    ------------------------ --------------- 3/5 [langchain-mongodb]
#    ------------------------ --------------- 3/5 [langchain-mongodb]
#    -------------------------------- ------- 4/5 [langgraph-checkpoint-mongodb]
#    ---------------------------------------- 5/5 [langgraph-checkpoint-mongodb]
#
# Successfully installed dnspython-2.7.0 langchain-mongodb-0.7.0 langgraph-checkpoint-mongodb-0.2.0 lark-1.2.2 pymongo-4.14.1

# %% [markdown]
# ## Long Term Memory
#
# We can use any database to save the conversation , For here we are using mongo db no SQL , for storing conversation
# and it will be loaded auto

# %%
from langchain.agents import create_agent

from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.checkpoint.mongodb import MongoDBSaver
from pymongo import MongoClient

llm = ChatGoogleGenerativeAI(
    api_key="<API-KEY>",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


# Create an agent with Checkpointer Memory
MONGODB_URI="mongodb+srv://skillustadinstitute:yCxxTQC5rvnSzt1A@cluster0.qhf38uc.mongodb.net/"
client = MongoClient(MONGODB_URI)
checkpointer = MongoDBSaver(client)

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
    checkpointer=checkpointer
)

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "what is my name"}]},
    config={"configurable": {"thread_id": "user123"}}
)

# Last Message
print(response['messages'][-1])
# Out:
# content='Your name is Zeeshan Ali.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--dd6c7dc0-19e1-4d72-91be-d7bc5eb6270d-0' usage_metadata={'input_tokens': 103, 'output_tokens': 8, 'total_tokens': 111, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# ### Email Sending API
