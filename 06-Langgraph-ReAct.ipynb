# %% [markdown]
# # LangChain
#
# ## Definition
# LangChain is a framework for building applications powered by large language models (LLMs). It provides tools to connect models with external data sources, memory, and reasoning chains, making LLMs more practical and powerful.

# %% [markdown]
# # LangGraph
#
# ## Definition
# LangGraph is a framework built on top of LangChain that allows developers to design, visualize, and control the flow of AI applications as graphs, making complex multi-step reasoning and agent workflows easier to manage.

# %%
# Installing Langgraph
# !pip install -U langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-0.6.6-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-0.3.74-py3-none-any.whl.metadata (5.8 kB)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.7.0,>=0.6.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.3-py3-none-any.whl.metadata (1.5 kB)
# Collecting pydantic>=2.7.4 (from langgraph)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Using cached xxhash-3.5.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.10.0-cp313-cp313-win_amd64.whl.metadata (44 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading orjson-3.11.2-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: certifi in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.8.3)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.10)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting langsmith>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.4.16-py3-none-any.whl.metadata (14 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core>=0.1->langgraph)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core>=0.1->langgraph)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting PyYAML>=5.3 (from langchain-core>=0.1->langgraph)
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.3.45->langchain-core>=0.1->langgraph)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith>=0.3.45->langchain-core>=0.1->langgraph)
#   Downloading zstandard-0.24.0-cp313-cp313-win_amd64.whl.metadata (3.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.4->langgraph)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.7.4->langgraph)
#   Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.7.4->langgraph)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading langgraph-0.6.6-py3-none-any.whl (153 kB)
# Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
# Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.3-py3-none-any.whl (52 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading langchain_core-0.3.74-py3-none-any.whl (443 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langsmith-0.4.16-py3-none-any.whl (375 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading orjson-3.11.2-cp313-cp313-win_amd64.whl (119 kB)
# Downloading ormsgpack-1.10.0-cp313-cp313-win_amd64.whl (121 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached xxhash-3.5.0-cp313-cp313-win_amd64.whl (30 kB)
# Downloading zstandard-0.24.0-cp313-cp313-win_amd64.whl (505 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, typing-inspection, tenacity, sniffio, PyYAML, pydantic-core, ormsgpack, orjson, jsonpointer, h11, annotated-types, requests-toolbelt, pydantic, jsonpatch, httpcore, anyio, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    ----------------------------------------  0/24 [zstandard]
#    --- ------------------------------------  2/24 [typing-inspection]
#    ----- ----------------------------------  3/24 [tenacity]
#    ----- ----------------------------------  3/24 [tenacity]
#    ----- ----------------------------------  3/24 [tenacity]
#    ------ ---------------------------------  4/24 [sniffio]
#    ------ ---------------------------------  4/24 [sniffio]
#    -------- -------------------------------  5/24 [PyYAML]
#    -------- -------------------------------  5/24 [PyYAML]
#    -------- -------------------------------  5/24 [PyYAML]
#    -------- -------------------------------  5/24 [PyYAML]
#    -------- -------------------------------  5/24 [PyYAML]
#    -------- -------------------------------  5/24 [PyYAML]
#    ---------- -----------------------------  6/24 [pydantic-core]
#    ---------- -----------------------------  6/24 [pydantic-core]
#    ----------- ----------------------------  7/24 [ormsgpack]
#    ------------- --------------------------  8/24 [orjson]
#    ---------------- ----------------------- 10/24 [h11]
#    ---------------- ----------------------- 10/24 [h11]
#    ---------------- ----------------------- 10/24 [h11]
#    ---------------- ----------------------- 10/24 [h11]
#    ---------------- ----------------------- 10/24 [h11]
#    ------------------ --------------------- 11/24 [annotated-types]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    -------------------- ------------------- 12/24 [requests-toolbelt]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    --------------------- ------------------ 13/24 [pydantic]
#    ----------------------- ---------------- 14/24 [jsonpatch]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    ------------------------- -------------- 15/24 [httpcore]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    -------------------------- ------------- 16/24 [anyio]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ---------------------------- ----------- 17/24 [httpx]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------ --------- 18/24 [langsmith]
#    ------------------------------- -------- 19/24 [langgraph-sdk]
#    ------------------------------- -------- 19/24 [langgraph-sdk]
#    ------------------------------- -------- 19/24 [langgraph-sdk]
#    ------------------------------- -------- 19/24 [langgraph-sdk]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    --------------------------------- ------ 20/24 [langchain-core]
#    ----------------------------------- ---- 21/24 [langgraph-checkpoint]
#    ----------------------------------- ---- 21/24 [langgraph-checkpoint]
#    ----------------------------------- ---- 21/24 [langgraph-checkpoint]
#    ----------------------------------- ---- 21/24 [langgraph-checkpoint]
#    ------------------------------------ --- 22/24 [langgraph-prebuilt]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    -------------------------------------- - 23/24 [langgraph]
#    ---------------------------------------- 24/24 [langgraph]
#
# Successfully installed PyYAML-6.0.2 annotated-types-0.7.0 anyio-4.10.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.74 langgraph-0.6.6 langgraph-checkpoint-2.1.1 langgraph-prebuilt-0.6.4 langgraph-sdk-0.2.3 langsmith-0.4.16 orjson-3.11.2 ormsgpack-1.10.0 pydantic-2.11.7 pydantic-core-2.33.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.1 xxhash-3.5.0 zstandard-0.24.0

# %%
# Instlling Google genertive ai 

# !pip install -U langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.10-py3-none-any.whl.metadata (7.2 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.75 (from langchain-google-genai)
#   Downloading langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-google-genai) (2.11.7)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.5)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached grpcio-1.74.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached grpcio_status-1.74.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (0.4.16)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2025.8.3)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (0.24.0)
# Requirement already satisfied: anyio in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.75->langchain-google-genai) (1.3.1)
# Downloading langchain_google_genai-2.1.10-py3-none-any.whl (49 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.6 MB/s  0:00:00
# Using cached google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached grpcio-1.74.0-cp313-cp313-win_amd64.whl (4.5 MB)
# Using cached grpcio_status-1.74.0-py3-none-any.whl (14 kB)
# Downloading langchain_core-0.3.75-py3-none-any.whl (443 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: filetype, pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, langchain-core, google-api-core, google-ai-generativelanguage, langchain-google-genai
#
#    ----------------------------------------  0/15 [filetype]
#    ----------------------------------------  0/15 [filetype]
#    ----------------------------------------  0/15 [filetype]
#    ----------------------------------------  0/15 [filetype]
#    ----------------------------------------  0/15 [filetype]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyasn1]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    ----- ----------------------------------  2/15 [protobuf]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    -------- -------------------------------  3/15 [grpcio]
#    ---------- -----------------------------  4/15 [cachetools]
#    ---------- -----------------------------  4/15 [cachetools]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ------------- --------------------------  5/15 [rsa]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ---------------- -----------------------  6/15 [pyasn1-modules]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    ------------------ ---------------------  7/15 [proto-plus]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    --------------------- ------------------  8/15 [googleapis-common-protos]
#    ------------------------ ---------------  9/15 [grpcio-status]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#    -------------------------- ------------- 10/15 [google-auth]
#   Attempting uninstall: langchain-core
#    -------------------------- ------------- 10/15 [google-auth]
#     Found existing installation: langchain-core 0.3.74
#    -------------------------- ------------- 10/15 [google-auth]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#     Uninstalling langchain-core-0.3.74:
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.74
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    ----------------------------- ---------- 11/15 [langchain-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    -------------------------------- ------- 12/15 [google-api-core]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    --------------------------------- ----- 13/15 [google-ai-generativelanguage]
#    ------------------------------------- -- 14/15 [langchain-google-genai]
#    ------------------------------------- -- 14/15 [langchain-google-genai]
#    ------------------------------------- -- 14/15 [langchain-google-genai]
#    ------------------------------------- -- 14/15 [langchain-google-genai]
#    ------------------------------------- -- 14/15 [langchain-google-genai]
#    ---------------------------------------- 15/15 [langchain-google-genai]
#
# Successfully installed cachetools-5.5.2 filetype-1.2.0 google-ai-generativelanguage-0.6.18 google-api-core-2.25.1 google-auth-2.40.3 googleapis-common-protos-1.70.0 grpcio-1.74.0 grpcio-status-1.74.0 langchain-core-0.3.75 langchain-google-genai-2.1.10 proto-plus-1.26.1 protobuf-6.32.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="dfklsjfklsdjfklsdjfcvkljdklfjklm,.,.m",  # Replace with your actual API key
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
messages = [
    (
        "system",
        "You are an software engineer who only answer related queries.",
    ),
    ("human", "How to make AI in 1 line"),
]
ai_msg = llm.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# `print("Hello!") if "hello" in input("You: ").lower() else print("I don't understand.")`

# %% [markdown]
# # Reasoning Agent
#
# ## Definition
# A Reasoning Agent is an AI agent that uses logical inference, knowledge, and reasoning techniques to make decisions rather than relying only on predefined rules.
#
# ## Key Features
# - Uses logic and knowledge representation.
# - Can deduce new facts from existing information.
# - Handles complex problems with multiple possible solutions.
#
# ## Example
# - A medical diagnosis system reasoning through symptoms to suggest possible diseases.

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (0.3.75)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (0.4.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)

# %%
from langgraph.prebuilt import create_react_agent

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="frffffffddd",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

agent = create_react_agent(
    model=llm,
    tools=[],
    prompt="You are a helpful assistant"
)

# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]}
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='what is the weather in sf', additional_kwargs={}, response_metadata={}, id='cb5a4175-9c0d-4999-94c8-b3cb15e4b891'),
#   AIMessage(content='As an AI, I don\'t have real-time access to live weather data.\n\nTo get the most up-to-date weather in San Francisco, I recommend checking a reliable weather source like:\n\n*   **Google Weather:** Just search "weather San Francisco"\n*   **Weather.com**\n*   **AccuWeather**\n*   **National Weather Service (weather.gov)**\n\n**Typically, San Francisco weather is known for being:**\n\n*   **Mild:** Rarely extremely hot or cold.\n*   **Foggy:** Especially in the mornings and evenings, particularly during the summer months.\n*   **Windy:** Especially near the coast.\n*   **Variable:** It can change quickly from one neighborhood to another.\n\nPlease check one of the sources above for the current conditions!', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--fec56e0c-2f16-4357-b536-24bab7fe1e6e-0', usage_metadata={'input_tokens': 12, 'output_tokens': 1260, 'total_tokens': 1272, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1091}})]}

# %% [markdown]
# ### Tool Callings

# %%
from langgraph.prebuilt import create_react_agent

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="API_KEY",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


def get_my_name() -> str:
    """Get the AI agent name."""
    return "Niki"

agent = create_react_agent(
    model=llm,
    tools=[get_weather,get_my_name],
    prompt="You are a helpful assistant"
)

# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "WWhat is your name?"}]}
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='WHat is your name', additional_kwargs={}, response_metadata={}, id='2fc93c0e-999d-4cb2-a6c0-dddc13d112d4'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_my_name', 'arguments': '{}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--2be5c1b9-8378-4772-941a-571307878b64-0', tool_calls=[{'name': 'get_my_name', 'args': {}, 'id': '3bf182f8-2592-4c25-8744-a8716b4b6fa2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 79, 'output_tokens': 55, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 43}}),
#   ToolMessage(content='Niki', name='get_my_name', id='e737e7d8-536d-4380-922b-249cbbe8e60c', tool_call_id='3bf182f8-2592-4c25-8744-a8716b4b6fa2'),
#   AIMessage(content='My name is Niki.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--97392f43-6a0f-462d-a534-772015fdf3eb-0', usage_metadata={'input_tokens': 109, 'output_tokens': 6, 'total_tokens': 115, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ### Weather Agent
# ### Internet Search
# ### Book page reader and summarizer
