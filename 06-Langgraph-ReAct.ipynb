# %% [markdown]
# # LangChain
#
# ## Definition
# LangChain is a framework for building applications powered by large language models (LLMs). It provides tools to connect models with external data sources, memory, and reasoning chains, making LLMs more practical and powerful.

# %% [markdown]
# # LangGraph
#
# ## Definition
# LangGraph is a framework built on top of LangChain that allows developers to design, visualize, and control the flow of AI applications as graphs, making complex multi-step reasoning and agent workflows easier to manage.

# %%
# Installing Langgraph
# !pip install -U langgraph
# Out:
# Collecting langgraph
#   Using cached langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Using cached langchain_core-1.0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph)
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Using cached langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting pydantic>=2.7.4 (from langgraph)
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Using cached xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core>=0.1->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.4.45-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core>=0.1->langgraph)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core>=0.1->langgraph)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core>=0.1->langgraph)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.4->langgraph)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.4->langgraph)
#   Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.4->langgraph)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached langchain_core-1.0.7-py3-none-any.whl (472 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.45-py3-none-any.whl (411 kB)
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl (131 kB)
# Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl (112 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Using cached zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, urllib3, typing-extensions, tenacity, sniffio, pyyaml, ormsgpack, orjson, jsonpointer, idna, h11, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, jsonpatch, httpcore, anyio, requests-toolbelt, pydantic, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    ---- -----------------------------------  3/30 [typing-extensions]
#    ----- ----------------------------------  4/30 [tenacity]
#    ------ ---------------------------------  5/30 [sniffio]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    ---------- -----------------------------  8/30 [orjson]
#    ------------- -------------------------- 10/30 [idna]
#    ------------- -------------------------- 10/30 [idna]
#    -------------- ------------------------- 11/30 [h11]
#    -------------- ------------------------- 11/30 [h11]
#    ---------------- ----------------------- 12/30 [charset_normalizer]
#    ---------------- ----------------------- 12/30 [charset_normalizer]
#    ------------------ --------------------- 14/30 [annotated-types]
#    --------------------- ------------------ 16/30 [requests]
#    --------------------- ------------------ 16/30 [requests]
#    ---------------------- ----------------- 17/30 [pydantic-core]
#    ------------------------ --------------- 18/30 [jsonpatch]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ----------------------------- ---------- 22/30 [pydantic]
#    ------------------------------ --------- 23/30 [httpx]
#    ------------------------------ --------- 23/30 [httpx]
#    ------------------------------ --------- 23/30 [httpx]
#    ------------------------------ --------- 23/30 [httpx]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    --------------------------------- ------ 25/30 [langgraph-sdk]
#    --------------------------------- ------ 25/30 [langgraph-sdk]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langgraph-checkpoint]
#    ------------------------------------ --- 27/30 [langgraph-checkpoint]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    ---------------------------------------- 30/30 [langgraph]
#
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 certifi-2025.11.12 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-1.0.7 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.2.9 langsmith-0.4.45 orjson-3.11.4 ormsgpack-1.12.0 pydantic-2.12.4 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.5.0 xxhash-3.6.0 zstandard-0.25.0

# %%
# Instlling Google genertive ai 

# !pip install -U langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<1.0.0,>=0.9.0 (from langchain-google-genai)
#   Using cached google_ai_generativelanguage-0.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-google-genai) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-google-genai) (2.12.4)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.32.5)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (0.4.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (4.11.0)
# Requirement already satisfied: certifi in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (1.0.9)
# Requirement already satisfied: idna in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.5.0)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.5->langchain-google-genai) (1.3.1)
# Using cached langchain_google_genai-3.1.0-py3-none-any.whl (55 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_ai_generativelanguage-0.9.0-py3-none-any.whl (1.4 MB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 1.5 MB/s eta 0:00:03
#    ------ --------------------------------- 0.8/4.7 MB 1.5 MB/s eta 0:00:03
#    -------- ------------------------------- 1.0/4.7 MB 1.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.3/4.7 MB 1.5 MB/s eta 0:00:03
#    --------------- ------------------------ 1.8/4.7 MB 1.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.1/4.7 MB 1.4 MB/s eta 0:00:02
#    -------------------- ------------------- 2.4/4.7 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.7 MB 1.4 MB/s eta 0:00:02
#    ------------------------ --------------- 2.9/4.7 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.4/4.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 1.5 MB/s  0:00:03
# Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl (436 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: filetype, pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-ai-generativelanguage, langchain-google-genai
#
#    ----------------------------------------  0/14 [filetype]
#    ----------------------------------------  0/14 [filetype]
#    ----------------------------------------  0/14 [filetype]
#    ----------------------------------------  0/14 [filetype]
#    ----------------------------------------  0/14 [filetype]
#    ----------------------------------------  0/14 [filetype]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    ----------- ----------------------------  4/14 [cachetools]
#    ----------- ----------------------------  4/14 [cachetools]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    -------------- -------------------------  5/14 [rsa]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ------------------------- --------------  9/14 [grpcio-status]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    ------------------------------------- -- 13/14 [langchain-google-genai]
#    ------------------------------------- -- 13/14 [langchain-google-genai]
#    ------------------------------------- -- 13/14 [langchain-google-genai]
#    ---------------------------------------- 14/14 [langchain-google-genai]
#
# Successfully installed cachetools-6.2.2 filetype-1.2.0 google-ai-generativelanguage-0.9.0 google-api-core-2.28.1 google-auth-2.43.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 langchain-google-genai-3.1.0 proto-plus-1.26.1 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="API_KEY",  # Replace with your actual API key
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
messages = [
    (
        "system",
        "You are an software engineer who only answer related queries.",
    ),
    ("human", "WHo are you "),
]
ai_msg = llm.invoke(messages)

# %%
print(ai_msg.content)
# Out:
# I am an software engineer who only answers related queries.

# %% [markdown]
# # Reasoning Agent
#
# ## Definition
# A Reasoning Agent is an AI agent that uses logical inference, knowledge, and reasoning techniques to make decisions rather than relying only on predefined rules.
#
# ## Key Features
# - Uses logic and knowledge representation.
# - Can deduce new facts from existing information.
# - Handles complex problems with multiple possible solutions.
#
# ## Example
# - A medical diagnosis system reasoning through symptoms to suggest possible diseases.

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (0.4.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\786\desktop\sessions\agentic ai 2 month skill ustad\.venv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Downloading langchain-1.0.8-py3-none-any.whl (93 kB)
# Installing collected packages: langchain
# Successfully installed langchain-1.0.8

# %%
from langchain.agents import create_agent

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="API_KEY",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

agent = create_agent(
    model=llm,
    tools=[],
    system_prompt="You are a helpful assistant"
)

# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]}
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='what is the weather in sf', additional_kwargs={}, response_metadata={}, id='fa6995af-9ffc-4d45-9145-69bbd43f64bb'),
#   AIMessage(content="Let me check that for you!\n\nCurrently in San Francisco, it's **[Temperature]** with **[Conditions]**.\n\n*   **Temperature:** [e.g., 62°F (17°C)]\n*   **Feels like:** [e.g., 60°F (16°C)]\n*   **Conditions:** [e.g., Partly cloudy with some sun]\n*   **Wind:** [e.g., Light breeze from the west at 10 mph]\n*   **Humidity:** [e.g., 70%]\n\nThe forecast for today is a high of [e.g., 68°F (20°C)] and a low of [e.g., 55°F (13°C)], with [e.g., mostly clear skies later in the day].\n\n*(Please note: I don't have real-time access to live weather data. The information above is a placeholder. To get the most accurate, up-to-the-minute weather, I recommend checking a reliable weather app or website like Google Weather, AccuWeather, or The Weather Channel.)*", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--76655c4d-e1a1-4f28-9c30-38a1e494f8d8-0', usage_metadata={'input_tokens': 12, 'output_tokens': 1226, 'total_tokens': 1238, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 977}})]}

# %% [markdown]
# ### Tool Callings

# %%
from langchain.agents import create_agent

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    api_key="API_KEY",
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    # Real API 
    return f"It's always sunny in {city}!"


def get_my_name() -> str:
    """Get the AI agent name."""
    return "Niki"

agent = create_agent(
    model=llm,  
    tools=[get_weather,get_my_name],
    system_prompt="You are a helpful assistant"
)

# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "WWhat is your name?"}]}
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='WWhat is your name?', additional_kwargs={}, response_metadata={}, id='754592f6-ff38-4eb2-8617-de89e5b648b2'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_my_name', 'arguments': '{}'}, '__gemini_function_call_thought_signatures__': {'00a196c4-db89-4d4c-b591-20b085201b8d': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--7950e150-fdb9-4909-aaee-09bceb6e7d53-0', tool_calls=[{'name': 'get_my_name', 'args': {}, 'id': '00a196c4-db89-4d4c-b591-20b085201b8d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 80, 'output_tokens': 55, 'total_tokens': 135, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 43}}),
#   ToolMessage(content='Niki', name='get_my_name', id='57a2fcd1-59e7-4449-9c72-52dccde8114e', tool_call_id='00a196c4-db89-4d4c-b591-20b085201b8d'),
#   AIMessage(content=[{'type': 'text', 'text': 'My name is Niki.', 'extras': {'signature': 'Cq8BAdHtim/Csi5/INV12eagu5FY8kLpGvotwNqSXrYSyDSUKjz2aIJGk+wfUh4MsyxjF+j7bya+VvJhCg+nSET1L5X+gpFFUSvh69z/vYr/vexXoKc8UKYAPrHnJ9Lw2fEtbGjGiH3BMNNGGDacMhd2Mnp6qIluRo+6Z8okQSVogaG217uxRbxBHrFnVl6Tt1euRTJrzj8IAmBpYztTMrKHQC4b9ig5r0S6rfmy2Gz5QQ=='}}], additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--83fc4f56-83e4-4ced-84ff-bf817d85cf91-0', usage_metadata={'input_tokens': 110, 'output_tokens': 47, 'total_tokens': 157, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 41}})]}

# %% [markdown]
# ### Weather Agent
# ### Internet Search
# ### Book page reader and summarizer
